# %% [markdown]
# # Dasar Pemrograman Python

# %% [markdown]
# ##  1. Variabel
# > Tempat untuk menyimpan data dengan tipe tertentu

# %% [markdown]
# ## 2. Tipe Data Primitif (Dasar)
# 1. String
# 2. Integer
# 3. Float
# 4. Boolean

# %%
# Contoh tipe data String
nama = "Maudya Faza Ayunda"

# Contoh tipe data Integer
umur = 25

# Contoh tipe data Float
berat_badan = 56.23

# Contoh tipe data Boolean
status_pernikahan = True

# %%
print("Nama                : ", nama)
print("Umur                : ", umur, "Tahun")
print("Berat Badan         : ", berat_badan)
print("Status Pernikahan   : ", status_pernikahan)
# Out:
# Nama                :  Maudya Faza Ayunda
# Umur                :  25 Tahun
# Berat Badan         :  56.23
# Status Pernikahan   :  True

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Tipe data turunan (Non-Primitive)
# 1. Array
# 2. List
# 3. Tupple
# 4. Dictionary
# 5. Set
# 6. File

# %% [markdown]
# ### 3.1 Array
# ![Tipe Array](https://media.geeksforgeeks.org/wp-content/uploads/CommonArticleDesign2-min.png)

# %%
print ([u'\u0420\u043e\u0441\u0441\u0438\u044f'])

print('\u0420\u043e\u0441\u0441\u0438\u044f')
# Out:
# ['Россия']
# Россия

# %%
import array as arr
# Contoh Array
# value dalam array harus memiliki tipe data yang sama
# I untuk unsigned integer (integer positif), lihat gambar di atas
apapun_array = arr.array("I", [ 1,4,8,12,16, 128])
print(apapun_array)
# Out:
# array('I', [1, 4, 8, 12, 16, 128])

# %%
# Array akan error apabila didalamnya terdapat tipe data yang berbeda
bilangan_kelipatan_tiga = arr.array("I", [1,3,"enam",9])
print(bilangan_kelipatan_tiga)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-cfe717ff9765> in <module>()
#       1 # Array akan error apabila didalamnya terdapat tipe data yang berbeda
# ----> 2 bilangan_kelipatan_tiga = arr.array("I", [1,3,"enam",9])
#       3 print(bilangan_kelipatan_tiga)
#
# TypeError: an integer is required (got type str)

# %% [markdown]
# ### 3.2 List

# %%
# Value / nilai dalam list boleh memiliki tipe data yang berbeda
apapun_list = ["satu", 2, 3, 4.5, True]
print(apapun_list)
# Out:
# ['satu', 2, 3, 4.5, True]

# %%
apapun_list[3] = 'Bunga'
print(apapun_list)
# Out:
# ['satu', 2, 3, 'Bunga', True]

# %% [markdown]
# ### 3.3 Tupple
# > List yang isinya tidak bisa diubah.

# %%
apapun_tupple = (1,2,3,4,5)
apapun_tupple[0] = -100
print(apapun_tupple)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-86d302b82000> in <module>()
#       1 apapun_tupple = (1,2,3,4,5)
# ----> 2 apapun_tupple[0] = -100
#       3 print(apapun_tupple)
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# ### Cara mengakses Array dan List

# %%
# Dihitung dari nol
print(apapun_list[4])
print(apapun_tupple[3])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2008a9c0e1db> in <module>()
#       1 # Dihitung dari nol
# ----> 2 print(apapun_list[4])
#       3 print(apapun_tupple[3])
#
# NameError: name 'apapun_list' is not defined

# %% [markdown]
# ### 3.4 Dictionary
# > Tipe data yang memiliki key dan value

# %%
artis = {
    'nama': "Maudya Faza Ayunda",
    'umur': 25,
    'berat_badan': 63.5,
    'status_pernikahan': tidak
}

# %% [markdown]
# ### Cara mengakses Dictionary

# %%
print(artis['nama'])
print(artis['umur'])
print(artis['berat_badan'])
print(artis['status_pernikahan'])
# Out:
# Maudya Faza Ayunda
# 25
# 63.5
# False

# %% [markdown]
# ### 3.5 Set
# > Tipe data yang tidak ada data duplikat di dalamnya

# %%
nama = "Maudya Faza Ayunda"
nama1 = set(nama)
print(nama1)
 
s= set([ 10 , 10 , 20 , 30 , 30 , 30 ])
s
# Out:
# {'F', 'd', 'y', 'a', 'M', 'A', ' ', 'z', 'u', 'n'}
# {10, 20, 30}

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Operator
# 1. Operator Aritmatika
# 2. Operator Perbandingan
# 3. Operator Logika

# %% [markdown]
# ### 4.1 Operator Aritmatika

# %%
x = 7
y = 5

hasil_penjumlahan = x + y
hasil_pengurangan = x - y
hasil_perkalian = x * y
hasil_pembagian = x / y
hasil_modulus = x % y
hasil_floor_division = x // y
hasil_x_pangkat_y = x ** y

print("Hasil x + y =", hasil_penjumlahan)
print("Hasil x - y =", hasil_pengurangan)
print("Hasil x * y =", hasil_perkalian)
print("Hasil x / y =", hasil_pembagian)
print("Hasil x % y =", hasil_modulus)
print("Hasil x // y =", hasil_floor_division)
print("Hasil x ** y =", hasil_x_pangkat_y)
# Out:
# Hasil x + y = 12
# Hasil x - y = 2
# Hasil x * y = 35
# Hasil x / y = 1.4
# Hasil x % y = 2
# Hasil x // y = 1
# Hasil x ** y = 16807

# %% [markdown]
# ### 4.2 Operator Perbandingan

# %%
print("x > y =", x > y)
print("x < y =", x < y)
print("x >= y =", x >= y)
print("x <= y =", x <= y)
print("x != y =", x != y)
print("x == y =", x == y)
# Out:
# x > y = True
# x < y = False
# x >= y = True
# x <= y = False
# x != y = True
# x == y = False

# %% [markdown]
# ### 4.3 Operator Logika

# %%
a = True
b = False

print("a and b = ", a and b)
print("a or b = ", a or b)
print("not(a) =", not(a))
# Out:
# a and b =  False
# a or b =  True
# not(a) = False

# %% [markdown]
# ## 5. Percabangan (Conditional Statement)
# 1. `if...else`
# 2. `if...elif...else`

# %% [markdown]
# ### 5.1 `if...else`

# %%
nilai = 71


if nilai > 70:
    print("Selamat, kamu lulus")
else: # nilai_a <= 70
    print("Yah, kamu harus mengulang")
# Out:
# Selamat, kamu lulus

# %% [markdown]
# ### 5.2 `if...elif...else`

# %%
if nilai >= 90:
    print("Dapat nilai A")
elif nilai >= 80:
    print("Dapat nilai B")
elif nilai > 70:
    print("Dapat nilai C")
else:
    print("Dapat nilai D. Yah kamu harus mengulang")
# Out:
# Dapat nilai C

# %% [markdown]
# ## 6. Perulangan (Loop)
# 1. `for` Loop
# 2. `while` Loop

# %% [markdown]
# ### 6.1 `for` loop

# %%
for i in range(4):
  print("Hello world! (iterasi ke-", i, ")")
# Out:
# Hello world! (iterasi ke- 0 )
# Hello world! (iterasi ke- 1 )
# Hello world! (iterasi ke- 2 )
# Hello world! (iterasi ke- 3 )

# %%
fruits = ["Mangga", "Melon", "Pisang", "Apel", "Salak"]
for fruit in fruits:
  print("Saya suka makan", fruit)
# Out:
# Saya suka makan Mangga
# Saya suka makan Melon
# Saya suka makan Pisang
# Saya suka makan Apel
# Saya suka makan Salak

# %% [markdown]
# ### 6.2 `while` loop

# %%
j = 10
while j > 1:
  print("Hello friend (iterasi ke-", j, ")")
  j -= 2
# Out:
# Hello friend (iterasi ke- 10 )
# Hello friend (iterasi ke- 8 )
# Hello friend (iterasi ke- 6 )
# Hello friend (iterasi ke- 4 )
# Hello friend (iterasi ke- 2 )

# %% [markdown]
# ## Studi kasus: Penerimaan anggota koperasi sukanabung
# ![Koperasi](https://pelayananpublik.id/wp-content/uploads/2020/02/Screenshot_20200221-232401_1.jpg)
# > Koperasi sukanabung ingin melakukan rekrutmen anggota baru. Adapun kriterianya adalah sebagai berikut.
# - Tabungan dalam satu bulan minimal 10.000 rupiah
# - Usia 17-25 tahun
#
# > Adapun calon anggota koperasi sukanabung adalah sebagai berikut:
#
#
# | No | Nama   | Jml Tabungan (perbulan) | usia |
# |----|--------|-------------------------|------|
# | 1  | Entong | 12000                   | 16   |
# | 2  | Eneng  | 10000                   | 17   |
# | 3  | Bobby  | 9000                    | 25   |
# | 4  | Amir   | 15000                   | 26   |
# | 5  | Rendi  | 9900                    | 23   |
#
# 1. Buat data tersebut dalam bentuk dictionary
# 2. Buat program sederhana untuk menentukan apakah calon - calon tersebut sudah layak untuk menjadi anggota baru koperasi sukanabung.
# 3. Apabila ada calon anggota koperasi sukanabung yang tidak lolos, sebutkan alasannya mengapa yang bersangkutan tidak lolos.
# 4. Siapa saja kah yang lolos?

# %% [markdown]
# Jawaban Nomor 1

# %%
import yaml

anggotabaru = [ 
{
    'Nama' : "Entong",
    'Tabungan' : 12000,
    'Usia' : 16
},
{
    'Nama' : "Eneng",
    'Tabungan' : 10000,
    'Usia' : 17
},
{
    'Nama' : "Bobby",
    'Tabungan' : 9000,
    'Usia' : 25
},
{
    'Nama' : "Amir",
    'Tabungan' : 15000,
    'Usia' : 26
},
{
    'Nama' : "Rendi",
    'Tabungan' : 9900,
    'Usia' : 23
}
]

print(yaml.dump(anggotabaru))

# %% [markdown]
# Jawaban Nomor 2

# %%
for periksa in anggotabaru:
  if periksa['Tabungan'] >= 10000:
    if periksa['Usia'] >= 17 and periksa['Usia'] <=25:
      print(periksa['Nama']," - Lolos")
    else: 
      print(periksa['Nama'], "- Tidak Lolos, Usia tidak memenuhi kriteria")
  else: 
    print(periksa['Nama'], "- Tidak Lolos, Jumlah tabungan kurang dari jumlah minimum")

# %% [markdown]
# Jawaban Nomor 3

# %%
Berdasarkan Output :
-Entong - Tidak Lolos, Usia tidak memenuhi kriteria
-Bobby - Tidak Lolos, Jumlah tabungan kurang dari jumlah minimum
-Amir - Tidak Lolos, Usia tidak memenuhi kriteria
-Rendi - Tidak Lolos, Jumlah tabungan kurang dari jumlah minimum

# %% [markdown]
# Jawaban nomor 4

# %%
Eneng
